# %%
# ==========================================
# IMPORT REQUIRED LIBRARIES
# ==========================================

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# Ignore warnings

import warnings
warnings.filterwarnings("ignore")

# %%
# ==========================================
# LOAD DATASET
# ==========================================

df = pd.read_csv("C:/Users/DELL/Downloads/DATASETS/AI Job Market Dataset.csv")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
# ==========================================
# DATASET SHAPE
# ==========================================

print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 10345
# Columns : 19

# %%
# ==========================================
# FIRST FIVE RECORDS
# ==========================================

df.head()
# Out:
#    job_id                  job_title company_size company_industry    country  \
# 0       1                AI Engineer      Startup           Retail     Canada
# 1       2  Machine Learning Engineer          MNC       Technology  Australia
# 2       3  Machine Learning Engineer          MNC       Technology    Germany
# 3       4           Business Analyst      Startup       Healthcare    Germany
# 4       5             Data Scientist          MNC       Healthcare    Germany
#
#   remote_type experience_level  years_experience education_level  \
# 0      Remote           Senior                 2          Master
# 1      Hybrid              Mid                 0        Bachelor
# 2      Onsite              Mid                14          Master
# 3      Remote              Mid                 9          Master
# 4      Hybrid              Mid                 5          Master
#
#    skills_python  skills_sql  skills_ml  skills_deep_learning  skills_cloud  \
# ...

# %%
# ==========================================
# DATASET INFORMATION
# ==========================================

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10345 entries, 0 to 10344
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   job_id                10345 non-null  int64
#  1   job_title             10345 non-null  object
#  2   company_size          10345 non-null  object
#  3   company_industry      10345 non-null  object
#  4   country               10345 non-null  object
#  5   remote_type           10345 non-null  object
#  6   experience_level      10345 non-null  object
#  7   years_experience      10345 non-null  int64
#  8   education_level       10345 non-null  object
#  9   skills_python         10345 non-null  int64
#  10  skills_sql            10345 non-null  int64
#  11  skills_ml             10345 non-null  int64
#  12  skills_deep_learning  10345 non-null  int64
#  13  skills_cloud          10345 non-null  int64
#  14  salary                10345 non-null  int64
# ...

# %%
# ==========================================
# MISSING VALUES
# ==========================================

missing = df.isnull().sum()

print(missing)
# Out:
# job_id                  0
# job_title               0
# company_size            0
# company_industry        0
# country                 0
# remote_type             0
# experience_level        0
# years_experience        0
# education_level         0
# skills_python           0
# skills_sql              0
# skills_ml               0
# skills_deep_learning    0
# skills_cloud            0
# salary                  0
# job_posting_month       0
# job_posting_year        0
# hiring_urgency          0
# job_openings            0
# dtype: int64

# %%
# ==========================================
# MISSING VALUES
# ==========================================

missing = df.isnull().sum()

print(missing)
# Out:
# job_id                  0
# job_title               0
# company_size            0
# company_industry        0
# country                 0
# remote_type             0
# experience_level        0
# years_experience        0
# education_level         0
# skills_python           0
# skills_sql              0
# skills_ml               0
# skills_deep_learning    0
# skills_cloud            0
# salary                  0
# job_posting_month       0
# job_posting_year        0
# hiring_urgency          0
# job_openings            0
# dtype: int64

# %%
# ==========================================
# DUPLICATE RECORDS
# ==========================================

duplicates = df.duplicated().sum()

print("Duplicate Rows :", duplicates)
# Out:
# Duplicate Rows : 0

# %%
# ==========================================
# DESCRIPTIVE STATISTICS
# ==========================================

df.describe()
# Out:
#              job_id  years_experience  skills_python    skills_sql  \
# count  10345.000000      10345.000000   10345.000000  10345.000000
# mean    5173.000000          6.950507       0.493088      0.503045
# std     2986.488601          4.320054       0.499976      0.500015
# min        1.000000          0.000000       0.000000      0.000000
# 25%     2587.000000          3.000000       0.000000      0.000000
# 50%     5173.000000          7.000000       0.000000      1.000000
# 75%     7759.000000         11.000000       1.000000      1.000000
# max    10345.000000         14.000000       1.000000      1.000000
#
#           skills_ml  skills_deep_learning  skills_cloud        salary  \
# count  10345.000000          10345.000000  10345.000000   10345.00000
# mean       0.507878              0.498018      0.511455  113438.22726
# std        0.499962              0.500020      0.499893   31389.20106
# min        0.000000              0.000000      0.000000   45083.00000
# ...

# %%
# ==========================================
# CATEGORICAL SUMMARY
# ==========================================

df.describe(include="object")
# Out:
#                job_title company_size company_industry  country remote_type  \
# count              10345        10345            10345    10345       10345
# unique                 6            4                6        7           3
# top     Business Analyst      Startup       Technology  Germany      Remote
# freq                1773         2656             1787     1498        3513
#
#        experience_level education_level hiring_urgency
# count             10345           10345          10345
# unique                3               3              3
# top               Entry          Master           High
# freq               3513            3529           5195

# %%
# ==========================================
# TARGET VARIABLE DISTRIBUTION
# ==========================================

plt.figure(figsize=(8,5))

sns.histplot(
    df["salary"],
    bins=30,
    kde=True
)

plt.title("Salary Distribution")

plt.xlabel("Salary")

plt.ylabel("Frequency")

plt.show()

# %%
# ==========================================
# SALARY BOXPLOT
# ==========================================

plt.figure(figsize=(8,2))

sns.boxplot(
    x=df["salary"]
)

plt.title("Salary Boxplot")

plt.show()

# %%
# ==========================================
# CORRELATION MATRIX
# ==========================================

plt.figure(figsize=(10,6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap="Blues"
)

plt.title("Correlation Matrix")

plt.show()

# %%
# ==========================================
# TARGET SUMMARY
# ==========================================

print("Minimum Salary :", df["salary"].min())

print("Maximum Salary :", df["salary"].max())

print("Average Salary :", df["salary"].mean())

print("Median Salary :", df["salary"].median())
# Out:
# Minimum Salary : 45083
# Maximum Salary : 204143
# Average Salary : 113438.22725954567
# Median Salary : 113082.0

# %% [markdown]
# Business Findings
#
# • The dataset contains 10,345 AI job postings.
#
# • No missing values were found.
#
# • No duplicate records were identified.
#
# • Salary ranges from approximately 45K to 204K.
#
# • The average salary is around 113K.
#
# • Numerical variables show moderate relationships with salary.
#
# • The dataset is clean and suitable for Machine Learning.

# %%
                                               Phase - 2

# %%
# ==========================================
# DROP UNNECESSARY COLUMNS
# ==========================================

df = df.drop(columns=["job_id"])

print(df.head())
# Out:
#                    job_title company_size company_industry    country  \
# 0                AI Engineer      Startup           Retail     Canada
# 1  Machine Learning Engineer          MNC       Technology  Australia
# 2  Machine Learning Engineer          MNC       Technology    Germany
# 3           Business Analyst      Startup       Healthcare    Germany
# 4             Data Scientist          MNC       Healthcare    Germany
#
#   remote_type experience_level  years_experience education_level  \
# 0      Remote           Senior                 2          Master
# 1      Hybrid              Mid                 0        Bachelor
# 2      Onsite              Mid                14          Master
# 3      Remote              Mid                 9          Master
# 4      Hybrid              Mid                 5          Master
#
#    skills_python  skills_sql  skills_ml  skills_deep_learning  skills_cloud  \
# ...

# %%
# ==========================================
# IDENTIFY CATEGORICAL & NUMERICAL COLUMNS
# ==========================================

categorical_columns = df.select_dtypes(include="object").columns

numerical_columns = df.select_dtypes(exclude="object").columns

print("Categorical Columns")
print(categorical_columns)

print("\nNumerical Columns")
print(numerical_columns)
# Out:
# Categorical Columns
# Index(['job_title', 'company_size', 'company_industry', 'country',
#        'remote_type', 'experience_level', 'education_level', 'hiring_urgency'],
#       dtype='object')
#
# Numerical Columns
# Index(['years_experience', 'skills_python', 'skills_sql', 'skills_ml',
#        'skills_deep_learning', 'skills_cloud', 'salary', 'job_posting_month',
#        'job_posting_year', 'job_openings'],
#       dtype='object')

# %%
# ==========================================
# LABEL ENCODING
# ==========================================

from sklearn.preprocessing import LabelEncoder

label_encoders = {}

for column in categorical_columns:

    encoder = LabelEncoder()

    df[column] = encoder.fit_transform(df[column])

    label_encoders[column] = encoder

print("Categorical Columns Encoded Successfully")
# Out:
# Categorical Columns Encoded Successfully

# %%
# ==========================================
# ENCODED DATASET
# ==========================================

df.head()
# Out:
#    job_title  company_size  company_industry  country  remote_type  \
# 0          0             3                 4        1            2
# 1          5             1                 5        0            0
# 2          5             1                 5        2            1
# 3          1             3                 3        2            2
# 4          4             1                 3        2            0
#
#    experience_level  years_experience  education_level  skills_python  \
# 0                 2                 2                1              0
# 1                 1                 0                0              1
# 2                 1                14                1              1
# 3                 1                 9                1              0
# 4                 1                 5                1              1
#
#    skills_sql  skills_ml  skills_deep_learning  skills_cloud  salary  \
# ...

# %%
# ==========================================
# INPUT FEATURES
# ==========================================

X = df.drop("salary", axis=1)

print(X.head())
# Out:
#    job_title  company_size  company_industry  country  remote_type  \
# 0          0             3                 4        1            2
# 1          5             1                 5        0            0
# 2          5             1                 5        2            1
# 3          1             3                 3        2            2
# 4          4             1                 3        2            0
#
#    experience_level  years_experience  education_level  skills_python  \
# 0                 2                 2                1              0
# 1                 1                 0                0              1
# 2                 1                14                1              1
# 3                 1                 9                1              0
# 4                 1                 5                1              1
#
#    skills_sql  skills_ml  skills_deep_learning  skills_cloud  \
# 0           0          0                     1             0
# ...

# %%
# ==========================================
# TARGET VARIABLE
# ==========================================

y = df["salary"]

print(y.head())
# Out:
# 0    158322
# 1    163666
# 2    158556
# 3     95775
# 4    111873
# Name: salary, dtype: int64

# %%
# ==========================================
# FEATURES & TARGET SHAPE
# ==========================================

print("Features Shape :", X.shape)

print("Target Shape :", y.shape)
# Out:
# Features Shape : (10345, 17)
# Target Shape : (10345,)

# %%
# ==========================================
# TRAIN TEST SPLIT
# ==========================================

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(

    X,

    y,

    test_size=0.20,

    random_state=42

)

# %%
# ==========================================
# TRAIN TEST SHAPES
# ==========================================

print("Training Features :", X_train.shape)

print("Testing Features :", X_test.shape)

print("Training Target :", y_train.shape)

print("Testing Target :", y_test.shape)
# Out:
# Training Features : (8276, 17)
# Testing Features : (2069, 17)
# Training Target : (8276,)
# Testing Target : (2069,)

# %%
# ==========================================
# FEATURE SCALING
# ==========================================

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

print("Feature Scaling Completed")
# Out:
# Feature Scaling Completed

# %%
# ==========================================
# SAVE PROCESSED DATASET
# ==========================================

processed_df = pd.concat([X, y], axis=1)

processed_df.to_csv(
    "Processed_AI_Job_Dataset.csv",
    index=False
)

print("Processed Dataset Saved Successfully")
# Out:
# Processed Dataset Saved Successfully

# %% [markdown]
# Business Findings
#
# • The unique identifier (job_id) was removed because it does not contribute to salary prediction.
#
# • All categorical variables were converted into numerical values using Label Encoding.
#
# • The dataset was divided into input features (X) and target variable (Salary).
#
# • The data was split into 80% training and 20% testing to evaluate model performance on unseen data.
#
# • Feature scaling was also prepared for algorithms that benefit from standardized inputs.

# %%
                                                    Phase - 3

# %%
# ==========================================
# IMPORT MACHINE LEARNING ALGORITHMS
# ==========================================

from sklearn.linear_model import LinearRegression

from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import RandomForestRegressor

from sklearn.ensemble import GradientBoostingRegressor

# %%
# ==========================================
# IMPORT EVALUATION METRICS
# ==========================================

from sklearn.metrics import mean_absolute_error

from sklearn.metrics import mean_squared_error

from sklearn.metrics import r2_score

import numpy as np

# %%
# ==========================================
# MODEL EVALUATION FUNCTION
# ==========================================

def evaluate_model(model, X_test, y_test):

    predictions = model.predict(X_test)

    mae = mean_absolute_error(y_test, predictions)

    mse = mean_squared_error(y_test, predictions)

    rmse = np.sqrt(mse)

    r2 = r2_score(y_test, predictions)

    return mae, mse, rmse, r2

# %%
# ==========================================
# LINEAR REGRESSION
# ==========================================

linear_model = LinearRegression()

linear_model.fit(
    X_train_scaled,
    y_train
)

linear_results = evaluate_model(
    linear_model,
    X_test_scaled,
    y_test
)

print("Linear Regression Results")

print(linear_results)
# Out:
# Linear Regression Results
# (18367.89431980966, 437774331.02902037, np.float64(20923.05740156109), 0.5603331307671953)

# %%
# ==========================================
# DECISION TREE REGRESSOR
# ==========================================

decision_model = DecisionTreeRegressor(
    random_state=42
)

decision_model.fit(
    X_train,
    y_train
)

decision_results = evaluate_model(
    decision_model,
    X_test,
    y_test
)

print("Decision Tree Results")

print(decision_results)
# Out:
# Decision Tree Results
# (3423.96761720638, 18220386.35621073, np.float64(4268.534450629481), 0.981700845258293)

# %%
# ==========================================
# RANDOM FOREST REGRESSOR
# ==========================================

random_model = RandomForestRegressor(

    n_estimators=100,

    random_state=42

)

random_model.fit(
    X_train,
    y_train
)

random_results = evaluate_model(
    random_model,
    X_test,
    y_test
)

print("Random Forest Results")

print(random_results)
# Out:
# Random Forest Results
# (2712.4952392460127, 11102218.36624287, np.float64(3331.9991545981625), 0.98884978573515)

# %%
# ==========================================
# GRADIENT BOOSTING REGRESSOR
# ==========================================

gradient_model = GradientBoostingRegressor(

    random_state=42

)

gradient_model.fit(
    X_train,
    y_train
)

gradient_results = evaluate_model(

    gradient_model,

    X_test,

    y_test

)

print("Gradient Boosting Results")

print(gradient_results)
# Out:
# Gradient Boosting Results
# (2519.8271723060066, 8766161.460962404, np.float64(2960.770416793981), 0.9911959416266571)

# %%
# ==========================================
# MODEL COMPARISON
# ==========================================

comparison = pd.DataFrame({

    "Model":[

        "Linear Regression",

        "Decision Tree",

        "Random Forest",

        "Gradient Boosting"

    ],

    "MAE":[

        linear_results[0],

        decision_results[0],

        random_results[0],

        gradient_results[0]

    ],

    "MSE":[

        linear_results[1],

        decision_results[1],

        random_results[1],

        gradient_results[1]

    ],

    "RMSE":[

        linear_results[2],

        decision_results[2],

        random_results[2],

        gradient_results[2]

    ],

    "R2 Score":[

        linear_results[3],

        decision_results[3],

        random_results[3],

        gradient_results[3]

    ]

})

comparison
# Out:
#                Model           MAE           MSE          RMSE  R2 Score
# 0  Linear Regression  18367.894320  4.377743e+08  20923.057402  0.560333
# 1      Decision Tree   3423.967617  1.822039e+07   4268.534451  0.981701
# 2      Random Forest   2712.495239  1.110222e+07   3331.999155  0.988850
# 3  Gradient Boosting   2519.827172  8.766161e+06   2960.770417  0.991196

# %%
# ==========================================
# BEST MODEL
# ==========================================

best_model = comparison.sort_values(

    by="R2 Score",

    ascending=False

)

best_model
# Out:
#                Model           MAE           MSE          RMSE  R2 Score
# 3  Gradient Boosting   2519.827172  8.766161e+06   2960.770417  0.991196
# 2      Random Forest   2712.495239  1.110222e+07   3331.999155  0.988850
# 1      Decision Tree   3423.967617  1.822039e+07   4268.534451  0.981701
# 0  Linear Regression  18367.894320  4.377743e+08  20923.057402  0.560333

# %%
# ==========================================
# MODEL PERFORMANCE
# ==========================================

import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

plt.bar(

    comparison["Model"],

    comparison["R2 Score"]

)

plt.title("Model Comparison")

plt.xlabel("Models")

plt.ylabel("R² Score")

plt.xticks(rotation=20)

plt.show()

# %%
# ==========================================
# ACTUAL VS PREDICTED
# ==========================================

predictions = random_model.predict(X_test)

plt.figure(figsize=(7,7))

plt.scatter(

    y_test,

    predictions,

    alpha=0.6

)

plt.xlabel("Actual Salary")

plt.ylabel("Predicted Salary")

plt.title("Actual vs Predicted Salary")

plt.show()

# %%
# ==========================================
# RESIDUAL PLOT
# ==========================================

residuals = y_test - predictions

plt.figure(figsize=(8,5))

plt.scatter(

    predictions,

    residuals,

    alpha=0.5

)

plt.axhline(

    y=0,

    color="red",

    linestyle="--"

)

plt.xlabel("Predicted Salary")

plt.ylabel("Residuals")

plt.title("Residual Plot")

plt.show()

# %% [markdown]
# Business Findings
#
# • Four regression algorithms were trained and evaluated.
#
# • Model performance was measured using MAE, MSE, RMSE, and R² Score.
#
# • The model with the highest R² Score and lowest prediction error was selected as the final model.
#
# • Tree-based models (Random Forest and Gradient Boosting) are expected to outperform Linear Regression because they capture non-linear relationships between experience, skills, education, and salary.
#
# • The selected model can be used to estimate salaries for future AI job profiles based on candidate characteristics.

# %%
                                                      Phase - 4

# %%
# ==========================================
# FEATURE IMPORTANCE
# ==========================================

importance = pd.DataFrame({

    "Feature": X_train.columns,

    "Importance": random_model.feature_importances_

})

importance = importance.sort_values(

    by="Importance",

    ascending=False

)

importance
# Out:
#                  Feature  Importance
# 5       experience_level    0.414144
# 0              job_title    0.368132
# 1           company_size    0.070323
# 10             skills_ml    0.056713
# 11  skills_deep_learning    0.055264
# 12          skills_cloud    0.026158
# 6       years_experience    0.001468
# 13     job_posting_month    0.001433
# 3                country    0.001160
# 14      job_posting_year    0.001136
# 16          job_openings    0.001118
# 2       company_industry    0.000918
# 7        education_level    0.000558
# 4            remote_type    0.000545
# 8          skills_python    0.000331
# 9             skills_sql    0.000319
# 15        hiring_urgency    0.000280

# %%
# ==========================================
# FEATURE IMPORTANCE GRAPH
# ==========================================

plt.figure(figsize=(10,7))

plt.barh(

    importance["Feature"],

    importance["Importance"]

)

plt.xlabel("Importance")

plt.ylabel("Features")

plt.title("Feature Importance")

plt.gca().invert_yaxis()

plt.show()

# %%
# ==========================================
# TOP 10 FEATURES
# ==========================================

importance.head(10)
# Out:
#                  Feature  Importance
# 5       experience_level    0.414144
# 0              job_title    0.368132
# 1           company_size    0.070323
# 10             skills_ml    0.056713
# 11  skills_deep_learning    0.055264
# 12          skills_cloud    0.026158
# 6       years_experience    0.001468
# 13     job_posting_month    0.001433
# 3                country    0.001160
# 14      job_posting_year    0.001136

# %%
# ==========================================
# SAVE MODEL
# ==========================================

import joblib

joblib.dump(

    random_model,

    "salary_prediction_model.pkl"

)

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
# ==========================================
# SAVE SCALER
# ==========================================

joblib.dump(

    scaler,

    "scaler.pkl"

)

print("Scaler Saved Successfully")
# Out:
# Scaler Saved Successfully

# %%
# ==========================================
# SAVE LABEL ENCODERS
# ==========================================

joblib.dump(

    label_encoders,

    "label_encoders.pkl"

)

print("Encoders Saved Successfully")
# Out:
# Encoders Saved Successfully

# %%
# ==========================================
# SAMPLE PREDICTION
# ==========================================

sample = pd.DataFrame({

    "job_title":[0],

    "company_size":[1],

    "company_industry":[2],

    "country":[3],

    "remote_type":[2],

    "experience_level":[2],

    "years_experience":[8],

    "education_level":[1],

    "skills_python":[1],

    "skills_sql":[1],

    "skills_ml":[1],

    "skills_deep_learning":[1],

    "skills_cloud":[1],

    "job_posting_month":[6],

    "job_posting_year":[2026],

    "hiring_urgency":[0],

    "job_openings":[5]

})

# %%
# ==========================================
# PREDICT SALARY
# ==========================================

prediction = random_model.predict(sample)

print(

    "Predicted Salary :",

    round(prediction[0],2)

)
# Out:
# Predicted Salary : 197933.82

# %%
# ==========================================
# ACTUAL VS PREDICTED
# ==========================================

results = pd.DataFrame({

    "Actual Salary":y_test,

    "Predicted Salary":predictions

})

results.head(20)
# Out:
#       Actual Salary  Predicted Salary
# 1190         104470          99971.54
# 9948          84465          80038.97
# 4001          56793          59599.60
# 3287          87146          89318.43
# 2794         111024         115475.02
# 4151         126514         128912.87
# 3063         112340         116620.40
# 6101         101846         105378.15
# 8204          73847          75876.96
# 2252         107834         105772.78
# 2391         119808         120707.55
# 6595         142350         139671.69
# 2886          48614          48901.48
# 9946         155846         155827.49
# 7356         139522         140170.70
# 3881          68091          65849.31
# 3181          51529          48960.51
# 4417         112886         110808.26
# 1076         105104         105411.22
# 7831         118570         114698.38

# %%
# ==========================================
# PREDICTION ERROR
# ==========================================

results["Error"] = (

    results["Actual Salary"]

    -

    results["Predicted Salary"]

)

results.head()
# Out:
#       Actual Salary  Predicted Salary    Error
# 1190         104470          99971.54  4498.46
# 9948          84465          80038.97  4426.03
# 4001          56793          59599.60 -2806.60
# 3287          87146          89318.43 -2172.43
# 2794         111024         115475.02 -4451.02

# %%
# ==========================================
# ERROR DISTRIBUTION
# ==========================================

plt.figure(figsize=(8,5))

sns.histplot(

    results["Error"],

    bins=30,

    kde=True

)

plt.title("Prediction Error Distribution")

plt.show()

# %%
# ==========================================
# EXPORT RESULTS
# ==========================================

results.to_csv(

    "Prediction_Results.csv",

    index=False

)

print("Prediction Results Saved")
# Out:
# Prediction Results Saved

# %% [markdown]
# Business Findings
#
# • Feature Importance identified the most influential factors affecting salary.
#
# • Technical skills such as Machine Learning, Deep Learning, and Cloud Computing contribute significantly to salary prediction.
#
# • Years of experience remains one of the strongest predictors of salary.
#
# • The trained Random Forest model successfully predicts salaries for unseen AI job profiles.
#
# • The model and preprocessing objects were saved, enabling deployment without retraining.
